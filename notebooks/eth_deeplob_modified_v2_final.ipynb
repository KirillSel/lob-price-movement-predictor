# %%
# !pip install pandas_market_calendars
# Out:
# Collecting pandas_market_calendars
#   Downloading pandas_market_calendars-5.1.0-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.11/dist-packages (from pandas_market_calendars) (2.2.3)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.11/dist-packages (from pandas_market_calendars) (2025.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from pandas_market_calendars) (2.9.0.post0)
# Collecting exchange-calendars>=3.3 (from pandas_market_calendars)
#   Downloading exchange_calendars-4.10.1-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from exchange-calendars>=3.3->pandas_market_calendars) (1.26.4)
# Collecting pyluach (from exchange-calendars>=3.3->pandas_market_calendars)
#   Downloading pyluach-2.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: toolz in /usr/local/lib/python3.11/dist-packages (from exchange-calendars>=3.3->pandas_market_calendars) (1.0.0)
# Collecting korean_lunar_calendar (from exchange-calendars>=3.3->pandas_market_calendars)
#   Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1->pandas_market_calendars) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->pandas_market_calendars) (1.17.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->exchange-calendars>=3.3->pandas_market_calendars) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->exchange-calendars>=3.3->pandas_market_calendars) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->exchange-calendars>=3.3->pandas_market_calendars) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->exchange-calendars>=3.3->pandas_market_calendars) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->exchange-calendars>=3.3->pandas_market_calendars) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->exchange-calendars>=3.3->pandas_market_calendars) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->exchange-calendars>=3.3->pandas_market_calendars) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->exchange-calendars>=3.3->pandas_market_calendars) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->exchange-calendars>=3.3->pandas_market_calendars) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->exchange-calendars>=3.3->pandas_market_calendars) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->exchange-calendars>=3.3->pandas_market_calendars) (2024.2.0)
# Downloading pandas_market_calendars-5.1.0-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.9/123.9 kB 7.4 MB/s eta 0:00:00
# Downloading exchange_calendars-4.10.1-py3-none-any.whl (200 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 16.4 MB/s eta 0:00:00
# Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Downloading pyluach-2.2.0-py3-none-any.whl (25 kB)
# Installing collected packages: korean_lunar_calendar, pyluach, exchange-calendars, pandas_market_calendars
# Successfully installed exchange-calendars-4.10.1 korean_lunar_calendar-0.3.1 pandas_market_calendars-5.1.0 pyluach-2.2.0

# %%
# !pip install -U gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.4.26)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
import pandas as pd
import numpy as np
import os

from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from keras.utils import to_categorical
from keras.models import Model
from keras.optimizers import Adam
from keras.layers import Input, Conv2D, LeakyReLU, MaxPooling2D, concatenate, LSTM, Reshape, Dense, Bidirectional, Attention, Permute, Multiply, Lambda, RepeatVector, BatchNormalization, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint, CSVLogger
from keras.layers import Softmax, MultiHeadAttention, LayerNormalization, Add, Layer, Conv1D, GRU
from keras.saving import register_keras_serializable
import tensorflow.keras.backend as K
from keras.layers import GlobalAveragePooling1D
from tensorflow.keras.regularizers import l2

import pandas_market_calendars as mcal

# %%
import tensorflow as tf
import random

SEED = 2025

os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
print(tf.__version__)
# Out:
# 2.18.0

# %%
def moving_average(x, k):
    return np.convolve(x, np.ones(k), 'valid') / k

def compute_mid_price_changes(daily_data_dict, date_list, k):
    all_changes = []
    for date in date_list:
        price_bid = daily_data_dict[date][:, 0]
        size_bid = daily_data_dict[date][:, 1]
        price_ask = daily_data_dict[date][:, 2]
        size_ask = daily_data_dict[date][:, 3]
        mid_price = (price_ask * size_bid + price_bid * size_ask) / (size_ask + size_bid)

        future_avg = moving_average(mid_price, k)[1:]  # Skip current step
        current = mid_price[:-k]
        pct_change = (future_avg - current) / current
        all_changes.extend(pct_change)
    return np.array(all_changes)

# %%
import gdown

file_id = "1Awq8DwZovxzNuSSg2xGOKE56ZKYaqjKw"
gdown.download(f"https://drive.google.com/uc?id={file_id}", output="combined_orderbooks_eth_large.csv", quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Awq8DwZovxzNuSSg2xGOKE56ZKYaqjKw
# From (redirected): https://drive.google.com/uc?id=1Awq8DwZovxzNuSSg2xGOKE56ZKYaqjKw&confirm=t&uuid=a6f0c13a-303e-4515-862a-9c3445c4a7db
# To: /kaggle/working/combined_orderbooks_eth_large.csv
# 100%|██████████| 234M/234M [00:00<00:00, 350MB/s]
# 'combined_orderbooks_eth_large.csv'

# %%
df = pd.read_csv("combined_orderbooks_eth_large.csv")

# %%
df
# Out:
#          timestamp  bid_price_1  bid_size_1  ask_price_1  ask_size_1  \
# 0       1745798400      1790.31       38.59      1790.32       15.04
# 1       1745798401      1790.31       38.71      1790.32       14.93
# 2       1745798402      1790.31       18.98      1790.32       27.39
# 3       1745798403      1790.31       27.70      1790.32        9.89
# 4       1745798404      1790.31       27.58      1790.32       10.34
# ...            ...          ...         ...          ...         ...
# 863996  1746662396      1810.48       52.96      1810.49       62.14
# 863997  1746662397      1810.48        6.68      1810.49       74.63
# 863998  1746662398      1810.48       19.02      1810.49       55.80
# 863999  1746662399      1810.26        4.74      1810.27       93.51
# 864000  1746662400      1810.26        7.95      1810.27      100.01
#
#         bid_price_2  bid_size_2  ask_price_2  ask_size_2  bid_price_3  ...  \
# 0           1790.30        0.68      1790.34        0.08      1790.28  ...
# 1           1790.30        0.68      1790.34        0.08      1790.28  ...
# 2           1790.28        0.02      1790.33        0.03      1790.26  ...
# 3           1790.28        0.02      1790.34        0.08      1790.26  ...
# 4           1790.28        0.02      1790.34        0.08      1790.26  ...
# ...             ...         ...          ...         ...          ...  ...
# 863996      1810.47        1.53      1810.50        0.01      1810.45  ...
# 863997      1810.47        0.02      1810.50        0.01      1810.45  ...
# 863998      1810.46        0.02      1810.50        0.01      1810.45  ...
# 863999      1810.25        0.02      1810.30        2.95      1810.24  ...
# 864000      1810.25        0.02      1810.29        3.18      1810.24  ...
#
#         ask_price_8  ask_size_8  bid_price_9  bid_size_9  ask_price_9  \
# 0           1790.43        0.02      1790.21        0.02      1790.45
# 1           1790.43        0.02      1790.21        0.02      1790.45
# 2           1790.41        1.00      1790.20        1.12      1790.43
# 3           1790.43        0.02      1790.20        1.12      1790.45
# 4           1790.43        0.02      1790.20        1.12      1790.45
# ...             ...         ...          ...         ...          ...
# 863996      1810.58        5.06      1810.36        0.02      1810.59
# 863997      1810.59       16.34      1810.36        0.02      1810.60
# 863998      1810.59       16.34      1810.36        8.30      1810.60
# 863999      1810.38        0.01      1810.13        3.87      1810.40
# 864000      1810.36       10.91      1810.13        0.03      1810.37
#
#         ask_size_9  bid_price_10  bid_size_10  ask_price_10  ask_size_10
# 0             0.04       1790.20         1.12       1790.47         0.02
# 1             0.04       1790.20         1.12       1790.47         0.02
# 2             0.02       1790.19         0.16       1790.45         0.02
# 3             0.02       1790.19         0.16       1790.47         0.02
# 4             0.02       1790.19         0.16       1790.47         0.02
# ...            ...           ...          ...           ...          ...
# 863996       16.34       1810.35         6.29       1810.60         1.97
# 863997        1.97       1810.35         6.29       1810.61         0.03
# 863998        1.97       1810.35         6.29       1810.61         0.03
# 863999        1.97       1810.12         0.17       1810.41         0.30
# 864000       23.04       1810.12         0.17       1810.38         0.01
#
# [864001 rows x 41 columns]

# %%
df = df.sort_values(by=['timestamp']).reset_index(drop=True)

# %%
df['date'] = pd.to_datetime(df['timestamp'], unit='s')
df['date'] = df['date'].dt.date
df['date'] = df['date'].apply(lambda x: str(x))

# %%
df = df[df['date'] != '2025-05-08'].reset_index(drop=True)

# %%
numeric_columns = [col for col in df.columns if col not in ['timestamp', 'date']]

# %%
dates_str_list = list(df['date'].unique())

# %%
daily_data_dict = {}

# %%
for i in range(len(dates_str_list)):
    date = dates_str_list[i]
    if date not in daily_data_dict.keys():
        daily_data_dict[date] = np.array(df[df['date']==dates_str_list[i]][numeric_columns])

# %%
mid_price_changes = compute_mid_price_changes(daily_data_dict, ['2025-04-28'], 8)

# %%
alpha = np.quantile(mid_price_changes, 0.3)

# %%
alpha
# Out:
# -6.495761631192181e-05

# %%
daily_data_dict.pop('2025-04-28')
# Out:
# array([[1.79031e+03, 3.85900e+01, 1.79032e+03, ..., 1.12000e+00,
#         1.79047e+03, 2.00000e-02],
#        [1.79031e+03, 3.87100e+01, 1.79032e+03, ..., 1.12000e+00,
#         1.79047e+03, 2.00000e-02],
#        [1.79031e+03, 1.89800e+01, 1.79032e+03, ..., 1.60000e-01,
#         1.79045e+03, 2.00000e-02],
#        ...,
#        [1.79890e+03, 1.36890e+02, 1.79891e+03, ..., 2.00000e-02,
#         1.79901e+03, 2.00000e-02],
#        [1.79890e+03, 1.39910e+02, 1.79891e+03, ..., 2.00000e-02,
#         1.79901e+03, 2.00000e-02],
#        [1.79890e+03, 1.38780e+02, 1.79891e+03, ..., 2.00000e-02,
#         1.79901e+03, 2.00000e-02]])

# %%
dates_str_list = dates_str_list[1:]

# %%
normalization_mean_dict = {}
normalization_stddev_dict = {}

# %%
for i in range(5,len(dates_str_list)):
    date = dates_str_list[i]

    if (date not in normalization_mean_dict.keys()) or (date not in normalization_stddev_dict.keys()):
        look_back_dates_list = dates_str_list[(i-5):i]
        prev_5_day_orderbook_np = None
        for look_back_date in look_back_dates_list:
            if prev_5_day_orderbook_np is None:
                prev_5_day_orderbook_np = daily_data_dict[look_back_date]
            else:
                prev_5_day_orderbook_np = np.vstack((prev_5_day_orderbook_np, daily_data_dict[look_back_date]))


        price_mean = prev_5_day_orderbook_np[:,range(0,prev_5_day_orderbook_np.shape[1],2)].mean()
        price_std = prev_5_day_orderbook_np[:,range(0,prev_5_day_orderbook_np.shape[1],2)].std()
        size_mean = prev_5_day_orderbook_np[:,range(1,prev_5_day_orderbook_np.shape[1],2)].mean()
        size_std = prev_5_day_orderbook_np[:,range(1,prev_5_day_orderbook_np.shape[1],2)].std()

        normalization_mean_dict[date] = np.repeat([[price_mean,size_mean]], 20, axis=0).flatten()
        normalization_stddev_dict[date] = np.repeat([[price_std,size_std]], 20, axis=0).flatten()

# %%
daily_norm_data_dict = {}
for i in range(5, len(dates_str_list)):
    date = dates_str_list[i]
    if date not in daily_norm_data_dict.keys():
        raw_data = daily_data_dict[date]

        # Шаг 1: Нормализация базовых 40 признаков
        norm_data = (raw_data - normalization_mean_dict[date]) / normalization_stddev_dict[date]

        # Шаг 2: Feature engineering — доп. признаки

        # Mid-price = (ask_price_1 + bid_price_1) / 2
        mid_price = ((raw_data[:, 2] + raw_data[:, 0]) / 2).reshape(-1, 1)

        # Spread = ask_price_1 - bid_price_1
        spread = (raw_data[:, 2] - raw_data[:, 0]).reshape(-1, 1)

        # Imbalance = (bid_depth - ask_depth) / (bid_depth + ask_depth)
        bid_depth = raw_data[:, [i for i in range(1, 40, 4)]].sum(axis=1)
        ask_depth = raw_data[:, [i for i in range(3, 40, 4)]].sum(axis=1)
        imbalance = ((bid_depth - ask_depth) / (bid_depth + ask_depth + 1e-8)).reshape(-1, 1)

        # Объединяем все признаки в один массив
        full_data = np.hstack([norm_data, mid_price, spread, imbalance])

        daily_norm_data_dict[date] = full_data

# %%
list(daily_data_dict.keys())[5:]
# Out:
# ['2025-05-04', '2025-05-05', '2025-05-06', '2025-05-07']

# %%
def generate_labels(k, alpha, daily_data_dict):
    daily_label_dict = {}
    for date in list(daily_data_dict.keys())[5:]:
        price_bid = daily_data_dict[date][:,0]
        size_bid = daily_data_dict[date][:,1]
        price_ask = daily_data_dict[date][:,2]
        size_ask = daily_data_dict[date][:,3]
        mid_price = (price_ask * size_bid + price_bid * size_ask) / (size_ask + size_bid)
        future_k_avg_mid_price = moving_average(mid_price, k)[1:]
        print(future_k_avg_mid_price.shape, mid_price[:-k].shape)
        change_pct = (future_k_avg_mid_price - mid_price[:-k])/mid_price[:-k]
        print(change_pct, len(change_pct))
        y_label = (-(change_pct < -alpha).astype(int)) + (change_pct > alpha).astype(int)

        daily_label_dict[date] = y_label.reshape(-1,1)
    return daily_label_dict

# %%
def generate_X_y(k, alpha, timestamp_per_sample, daily_norm_data_dict, daily_data_dict):
    #k is the number of future timesteps used to generate the label y
    data_x = None
    for date in daily_norm_data_dict.keys():
        if data_x is None:
            data_x = daily_norm_data_dict[date].copy()[:-k,:]
        else:
            data_x = np.vstack((data_x, daily_norm_data_dict[date][:-k,:]))

    daily_label_dict = generate_labels(k, alpha, daily_data_dict)
    data_y = None
    for date in daily_label_dict.keys():
        if data_y is None:
            data_y = daily_label_dict[date].copy()
        else:
            data_y = np.vstack((data_y, daily_label_dict[date]))

    [N, P_x] = data_x.shape

    x = np.zeros([(N-timestamp_per_sample+1), timestamp_per_sample, P_x])

    for i in range(N-timestamp_per_sample+1):
        x[i] = data_x[i:(i+timestamp_per_sample), :]

    x = x.reshape(x.shape + (1,))
    y = data_y[(timestamp_per_sample-1):]
    y = to_categorical(y, 3)

    return x, y

# %%
daily_norm_data_dict.pop('2025-05-07')
daily_data_dict.pop('2025-05-07')
# Out:
# array([[1.81636e+03, 5.87400e+01, 1.81637e+03, ..., 4.00000e-02,
#         1.81650e+03, 1.97400e+01],
#        [1.81679e+03, 1.34600e+01, 1.81680e+03, ..., 4.60000e-01,
#         1.81692e+03, 3.36000e+00],
#        [1.81681e+03, 2.49000e+00, 1.81682e+03, ..., 2.00000e-02,
#         1.81693e+03, 3.40000e-01],
#        ...,
#        [1.81048e+03, 6.68000e+00, 1.81049e+03, ..., 6.29000e+00,
#         1.81061e+03, 3.00000e-02],
#        [1.81048e+03, 1.90200e+01, 1.81049e+03, ..., 6.29000e+00,
#         1.81061e+03, 3.00000e-02],
#        [1.81026e+03, 4.74000e+00, 1.81027e+03, ..., 1.70000e-01,
#         1.81041e+03, 3.00000e-01]])

# %%
X,y = generate_X_y(k=8, alpha=alpha, timestamp_per_sample=100,
                   daily_norm_data_dict= daily_norm_data_dict,
                   daily_data_dict = daily_data_dict)
# Out:
# (86392,) (86392,)
# [ 5.57455492e-05  1.01256770e-05  1.72004573e-05 ... -4.25251081e-05
#  -4.80992974e-05 -5.47959905e-05] 86392
# (86392,) (86392,)
# [-1.89716698e-04 -2.51378867e-04 -3.24225802e-04 ...  3.04242716e-05
#  -5.76103946e-08  1.98654638e-06] 86392
# (86392,) (86392,)
# [ 1.94291057e-04 -1.46386669e-06 -2.07872586e-05 ...  6.15573640e-05
#   8.43943060e-05  1.04291292e-04] 86392

# %%
del daily_norm_data_dict
del daily_data_dict
del dates_str_list
del normalization_mean_dict
del normalization_stddev_dict
del df
import gc; gc.collect()
# Out:
# 68

# %%
y[:, 0].sum(), y[:, 1].sum(), y[:, 2].sum()
# Out:
# (137151.0, 61099.0, 60827.0)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    random_state=SEED,
    shuffle=False
)

# %%
lookback_timestep = 100
feature_num = 43

#Conv param
conv_filter_num = 16

#Inception module param
inception_num = 32

#LSTM param
LSTM_num = 64

#Activation param
leaky_relu_alpha = 0.01

# ADAM is used
learning_rate = 1e-3
adam_epsilon = 1e-7
optimizer = Adam(learning_rate=learning_rate, epsilon=adam_epsilon)

# accuracy is used for stopping training
metrics = ['accuracy']

num_epoch = 100
#stop training when validation accuracy does not improve for 20 epochs
stop_epoch_num = 50

batch_size = 256

# %%
@register_keras_serializable()
def focal_loss(gamma=2., alpha=0.25):
    def loss(y_true, y_pred):
        y_pred = K.clip(y_pred, 1e-8, 1. - 1e-8)
        cross_entropy = -y_true * K.log(y_pred)
        weight = alpha * K.pow(1 - y_pred, gamma)
        loss = weight * cross_entropy
        return K.mean(K.sum(loss, axis=1))
    return loss

# %%
def initiate_DeepLOB_modified_model(lookback_timestep, feature_num, conv_filter_num, inception_num, LSTM_num, leaky_relu_alpha,
                        optimizer, metrics):

    input_tensor = Input(shape=(lookback_timestep, feature_num, 1))
    print("Input tensor shape:", input_tensor.shape)

    # --- Conv Block 1 ---
    conv_layer1 = Conv2D(conv_filter_num, (1, 2), strides=(1, 2))(input_tensor)
    print("Conv1-1 (1x2) shape:", conv_layer1.shape)

    conv_layer1 = LeakyReLU(alpha=leaky_relu_alpha)(conv_layer1)
    print("Conv1-1 after LeakyReLU:", conv_layer1.shape)

    conv_layer1 = Conv2D(conv_filter_num, (4,1), padding='same')(conv_layer1)
    print("Conv1-2 (4x1) shape:", conv_layer1.shape)

    conv_layer1 = LeakyReLU(alpha=leaky_relu_alpha)(conv_layer1)

    conv_layer1 = Conv2D(conv_filter_num, (4,1), padding='same')(conv_layer1)
    print("Conv1-3 (4x1) shape:", conv_layer1.shape)

    conv_layer1 = LeakyReLU(alpha=leaky_relu_alpha)(conv_layer1)

    # --- Conv Block 2 ---
    conv_layer2 = Conv2D(conv_filter_num, (1,2), strides=(1, 2))(conv_layer1)
    print("Conv2-1 (1x2) shape:", conv_layer2.shape)

    conv_layer2 = LeakyReLU(alpha=leaky_relu_alpha)(conv_layer2)

    conv_layer2 = Conv2D(conv_filter_num, (4,1), padding='same')(conv_layer2)
    print("Conv2-2 (4x1) shape:", conv_layer2.shape)

    conv_layer2 = LeakyReLU(alpha=leaky_relu_alpha)(conv_layer2)

    conv_layer2 = Conv2D(conv_filter_num, (4,1), padding='same')(conv_layer2)
    print("Conv2-3 (4x1) shape:", conv_layer2.shape)

    conv_layer2 = LeakyReLU(alpha=leaky_relu_alpha)(conv_layer2)

    # --- Conv Block 3 ---
    conv_layer3 = Conv2D(conv_filter_num, (1,10))(conv_layer2)
    print("Conv3-1 (1x10) shape:", conv_layer3.shape)

    conv_layer3 = LeakyReLU(alpha=leaky_relu_alpha)(conv_layer3)

    conv_layer3 = Conv2D(conv_filter_num, (4,1), padding='same')(conv_layer3)
    print("Conv3-2 (4x1) shape:", conv_layer3.shape)

    conv_layer3 = LeakyReLU(alpha=leaky_relu_alpha)(conv_layer3)

    conv_layer3 = Conv2D(conv_filter_num, (4,1), padding='same')(conv_layer3)
    print("Conv3-3 (4x1) shape:", conv_layer3.shape)

    conv_layer3 = LeakyReLU(alpha=leaky_relu_alpha)(conv_layer3)

    # --- Inception Module ---
    inception_module1 = Conv2D(inception_num, (1,1), padding='same')(conv_layer3)
    inception_module1 = LeakyReLU(alpha=leaky_relu_alpha)(inception_module1)
    print("Inception branch 1 - after 1x1 LeakyReLU:", inception_module1.shape)

    inception_module1 = Conv2D(inception_num, (3,1), padding='same')(inception_module1)
    inception_module1 = LeakyReLU(alpha=leaky_relu_alpha)(inception_module1)
    print("Inception branch 1 - after 3x1:", inception_module1.shape)

    inception_module2 = Conv2D(inception_num, (1,1), padding='same')(conv_layer3)
    inception_module2 = LeakyReLU(alpha=leaky_relu_alpha)(inception_module2)
    print("Inception branch 2 - after 1x1 LeakyReLU:", inception_module2.shape)

    inception_module2 = Conv2D(inception_num, (5,1), padding='same')(inception_module2)
    inception_module2 = LeakyReLU(alpha=leaky_relu_alpha)(inception_module2)
    print("Inception branch 2 - after 5x1:", inception_module2.shape)

    inception_module3 = MaxPooling2D((3,1), strides=(1,1), padding='same')(conv_layer3)
    print("Inception branch 3 - after MaxPooling:", inception_module3.shape)

    inception_module3 = Conv2D(inception_num, (1,1), padding='same')(inception_module3)
    print("Inception branch 3 - after 1x1 conv:", inception_module3.shape)

    inception_module3 = LeakyReLU(alpha=leaky_relu_alpha)(inception_module3)
    print("Inception branch 3 - after LeakyReLU:", inception_module3.shape)

    # Объединяем
    inception_module_final = concatenate([inception_module1, inception_module2, inception_module3], axis=3)
    print("After concatenation:", inception_module_final.shape)

    # Преобразуем для LSTM или Attention
    inception_module_final = Reshape((inception_module_final.shape[1], inception_module_final.shape[3]))(inception_module_final)
    print("After reshape:", inception_module_final.shape)

    # Bidirectional GRU вместо LSTM
    lstm_out = Bidirectional(GRU(LSTM_num, return_sequences=True))(inception_module_final)
    print("Bidirectional GRU:", lstm_out.shape)

    # Attention слой (self-attention по временной оси)
    attention_scores = Dense(1, activation='tanh')(lstm_out)
    attention_weights = Softmax(axis=1)(attention_scores)
    print("Attention weights:", attention_weights.shape)
    @register_keras_serializable()
    def attention_context(x):
        return tf.reduce_sum(x[0] * x[1], axis=1)
    
    @register_keras_serializable()
    def attention_output_shape(input_shapes):
        return (input_shapes[0][0], input_shapes[0][2])
    
    context = Lambda(attention_context, output_shape=attention_output_shape)([lstm_out, attention_weights])

    print("Context vector:", context.shape)

    # Fully Connected Layer with softmax activation function for output
    model_output = Dense(3, activation='softmax')(context)
    print(model_output.shape)

    DeepLOB_modified_model = Model(inputs=input_tensor, outputs= model_output)
    es = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1)

    DeepLOB_modified_model.compile(optimizer=optimizer, loss=focal_loss(), metrics=metrics)

    return DeepLOB_modified_model

# %%
DeepLOB_modified_model = initiate_DeepLOB_modified_model(
    lookback_timestep, feature_num, conv_filter_num, inception_num,
    LSTM_num, leaky_relu_alpha, optimizer, metrics
)
# Out:
# Input tensor shape: (None, 100, 43, 1)
# Conv1-1 (1x2) shape: (None, 100, 21, 16)
# Conv1-1 after LeakyReLU: (None, 100, 21, 16)
# Conv1-2 (4x1) shape: (None, 100, 21, 16)
# Conv1-3 (4x1) shape: (None, 100, 21, 16)
# Conv2-1 (1x2) shape: (None, 100, 10, 16)
# Conv2-2 (4x1) shape: (None, 100, 10, 16)
# Conv2-3 (4x1) shape: (None, 100, 10, 16)
# Conv3-1 (1x10) shape: (None, 100, 1, 16)
# Conv3-2 (4x1) shape: (None, 100, 1, 16)
# Conv3-3 (4x1) shape: (None, 100, 1, 16)
# Inception branch 1 - after 1x1 LeakyReLU: (None, 100, 1, 32)
# Inception branch 1 - after 3x1: (None, 100, 1, 32)
# Inception branch 2 - after 1x1 LeakyReLU: (None, 100, 1, 32)
# Inception branch 2 - after 5x1: (None, 100, 1, 32)
# Inception branch 3 - after MaxPooling: (None, 100, 1, 16)
# Inception branch 3 - after 1x1 conv: (None, 100, 1, 32)
# Inception branch 3 - after LeakyReLU: (None, 100, 1, 32)
# After concatenation: (None, 100, 1, 96)
# After reshape: (None, 100, 96)
# Bidirectional GRU: (None, 100, 128)
# Attention weights: (None, 100, 1)
# Context vector: (None, 128)
# (None, 3)

# %%
checkpoint_dir = 'checkpoints'
os.makedirs(checkpoint_dir, exist_ok=True)  
checkpoint_path = os.path.join(checkpoint_dir, 'best_model_modified_v2.keras')


model_checkpoint = ModelCheckpoint(
    filepath=checkpoint_path,
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=False,
    verbose=1
)


early_stopping = EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=stop_epoch_num,
    restore_best_weights=True,
    verbose=1
)

csv_logger = CSVLogger('training_log.csv')

# %%
y_train_labels = np.argmax(y_train, axis=1)
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train_labels), y=y_train_labels)
class_weight_dict = dict(enumerate(class_weights))

# %%
DeepLOB_modified_model.fit(
    X_train, y_train,
    epochs=num_epoch,
    batch_size=batch_size,
    validation_data=(X_test, y_test),
    callbacks=[early_stopping, model_checkpoint, csv_logger],
    class_weight=class_weight_dict,
    verbose=2
)
# Out:
# Epoch 1/100
# 2025-05-25 17:04:23.101312: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_16}}
# I0000 00:00:1748192671.203021     111 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-05-25 17:05:39.311995: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# Epoch 1: val_accuracy improved from -inf to 0.53146, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 84s - 103ms/step - accuracy: 0.5287 - loss: 0.1099 - val_accuracy: 0.5315 - val_loss: 0.1080
# Epoch 2/100
#
# Epoch 2: val_accuracy improved from 0.53146 to 0.53815, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 67s - 83ms/step - accuracy: 0.5345 - loss: 0.1079 - val_accuracy: 0.5382 - val_loss: 0.1073
# Epoch 3/100
#
# Epoch 3: val_accuracy improved from 0.53815 to 0.53854, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.5373 - loss: 0.1074 - val_accuracy: 0.5385 - val_loss: 0.1071
# Epoch 4/100
#
# Epoch 4: val_accuracy improved from 0.53854 to 0.53875, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.5385 - loss: 0.1072 - val_accuracy: 0.5388 - val_loss: 0.1069
# Epoch 5/100
#
# Epoch 5: val_accuracy did not improve from 0.53875
# 810/810 - 69s - 85ms/step - accuracy: 0.5399 - loss: 0.1070 - val_accuracy: 0.5367 - val_loss: 0.1070
# Epoch 6/100
#
# Epoch 6: val_accuracy improved from 0.53875 to 0.54790, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.5426 - loss: 0.1049 - val_accuracy: 0.5479 - val_loss: 0.1012
# Epoch 7/100
#
# Epoch 7: val_accuracy improved from 0.54790 to 0.55047, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.5499 - loss: 0.1009 - val_accuracy: 0.5505 - val_loss: 0.1004
# Epoch 8/100
#
# Epoch 8: val_accuracy improved from 0.55047 to 0.55247, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.5520 - loss: 0.1003 - val_accuracy: 0.5525 - val_loss: 0.1000
# Epoch 9/100
#
# Epoch 9: val_accuracy improved from 0.55247 to 0.55404, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.5535 - loss: 0.1000 - val_accuracy: 0.5540 - val_loss: 0.0998
# Epoch 10/100
#
# Epoch 10: val_accuracy did not improve from 0.55404
# 810/810 - 69s - 85ms/step - accuracy: 0.5544 - loss: 0.0998 - val_accuracy: 0.5538 - val_loss: 0.0997
# Epoch 11/100
#
# Epoch 11: val_accuracy improved from 0.55404 to 0.55508, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.5549 - loss: 0.0996 - val_accuracy: 0.5551 - val_loss: 0.0995
# Epoch 12/100
#
# Epoch 12: val_accuracy did not improve from 0.55508
# 810/810 - 69s - 85ms/step - accuracy: 0.5558 - loss: 0.0993 - val_accuracy: 0.5539 - val_loss: 0.0995
# Epoch 13/100
#
# Epoch 13: val_accuracy did not improve from 0.55508
# 810/810 - 69s - 85ms/step - accuracy: 0.5573 - loss: 0.0991 - val_accuracy: 0.5549 - val_loss: 0.0994
# Epoch 14/100
#
# Epoch 14: val_accuracy did not improve from 0.55508
# 810/810 - 69s - 85ms/step - accuracy: 0.5571 - loss: 0.0988 - val_accuracy: 0.5546 - val_loss: 0.0994
# Epoch 15/100
#
# Epoch 15: val_accuracy did not improve from 0.55508
# 810/810 - 69s - 85ms/step - accuracy: 0.5580 - loss: 0.0985 - val_accuracy: 0.5534 - val_loss: 0.0994
# Epoch 16/100
#
# Epoch 16: val_accuracy did not improve from 0.55508
# 810/810 - 69s - 85ms/step - accuracy: 0.5587 - loss: 0.0982 - val_accuracy: 0.5545 - val_loss: 0.0993
# Epoch 17/100
#
# Epoch 17: val_accuracy did not improve from 0.55508
# 810/810 - 69s - 85ms/step - accuracy: 0.5602 - loss: 0.0979 - val_accuracy: 0.5541 - val_loss: 0.0993
# Epoch 18/100
#
# Epoch 18: val_accuracy did not improve from 0.55508
# 810/810 - 69s - 85ms/step - accuracy: 0.5609 - loss: 0.0976 - val_accuracy: 0.5538 - val_loss: 0.0990
# Epoch 19/100
#
# Epoch 19: val_accuracy improved from 0.55508 to 0.55572, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.5613 - loss: 0.0973 - val_accuracy: 0.5557 - val_loss: 0.0988
# Epoch 20/100
#
# Epoch 20: val_accuracy did not improve from 0.55572
# 810/810 - 69s - 85ms/step - accuracy: 0.5627 - loss: 0.0969 - val_accuracy: 0.5556 - val_loss: 0.0985
# Epoch 21/100
#
# Epoch 21: val_accuracy improved from 0.55572 to 0.55672, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.5641 - loss: 0.0965 - val_accuracy: 0.5567 - val_loss: 0.0986
# Epoch 22/100
#
# Epoch 22: val_accuracy improved from 0.55672 to 0.55776, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.5651 - loss: 0.0960 - val_accuracy: 0.5578 - val_loss: 0.0982
# Epoch 23/100
#
# Epoch 23: val_accuracy did not improve from 0.55776
# 810/810 - 69s - 85ms/step - accuracy: 0.5663 - loss: 0.0955 - val_accuracy: 0.5552 - val_loss: 0.0985
# Epoch 24/100
#
# Epoch 24: val_accuracy did not improve from 0.55776
# 810/810 - 69s - 85ms/step - accuracy: 0.5673 - loss: 0.0951 - val_accuracy: 0.5511 - val_loss: 0.0987
# Epoch 25/100
#
# Epoch 25: val_accuracy did not improve from 0.55776
# 810/810 - 69s - 85ms/step - accuracy: 0.5679 - loss: 0.0946 - val_accuracy: 0.5553 - val_loss: 0.0980
# Epoch 26/100
#
# Epoch 26: val_accuracy did not improve from 0.55776
# 810/810 - 69s - 85ms/step - accuracy: 0.5702 - loss: 0.0939 - val_accuracy: 0.5566 - val_loss: 0.0975
# Epoch 27/100
#
# Epoch 27: val_accuracy did not improve from 0.55776
# 810/810 - 69s - 85ms/step - accuracy: 0.5720 - loss: 0.0933 - val_accuracy: 0.5526 - val_loss: 0.0976
# Epoch 28/100
#
# Epoch 28: val_accuracy did not improve from 0.55776
# 810/810 - 69s - 85ms/step - accuracy: 0.5737 - loss: 0.0925 - val_accuracy: 0.5577 - val_loss: 0.0972
# Epoch 29/100
#
# Epoch 29: val_accuracy improved from 0.55776 to 0.55898, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.5771 - loss: 0.0920 - val_accuracy: 0.5590 - val_loss: 0.0963
# Epoch 30/100
#
# Epoch 30: val_accuracy improved from 0.55898 to 0.56004, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.5780 - loss: 0.0912 - val_accuracy: 0.5600 - val_loss: 0.0960
# Epoch 31/100
#
# Epoch 31: val_accuracy did not improve from 0.56004
# 810/810 - 69s - 85ms/step - accuracy: 0.5793 - loss: 0.0906 - val_accuracy: 0.5595 - val_loss: 0.0963
# Epoch 32/100
#
# Epoch 32: val_accuracy improved from 0.56004 to 0.56048, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.5810 - loss: 0.0898 - val_accuracy: 0.5605 - val_loss: 0.0958
# Epoch 33/100
#
# Epoch 33: val_accuracy did not improve from 0.56048
# 810/810 - 69s - 85ms/step - accuracy: 0.5851 - loss: 0.0889 - val_accuracy: 0.5569 - val_loss: 0.0958
# Epoch 34/100
#
# Epoch 34: val_accuracy improved from 0.56048 to 0.56363, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.5875 - loss: 0.0882 - val_accuracy: 0.5636 - val_loss: 0.0952
# Epoch 35/100
#
# Epoch 35: val_accuracy did not improve from 0.56363
# 810/810 - 69s - 85ms/step - accuracy: 0.5893 - loss: 0.0875 - val_accuracy: 0.5608 - val_loss: 0.0957
# Epoch 36/100
#
# Epoch 36: val_accuracy improved from 0.56363 to 0.56836, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.5920 - loss: 0.0867 - val_accuracy: 0.5684 - val_loss: 0.0940
# Epoch 37/100
#
# Epoch 37: val_accuracy did not improve from 0.56836
# 810/810 - 69s - 85ms/step - accuracy: 0.5932 - loss: 0.0860 - val_accuracy: 0.5657 - val_loss: 0.0946
# Epoch 38/100
#
# Epoch 38: val_accuracy did not improve from 0.56836
# 810/810 - 69s - 85ms/step - accuracy: 0.5969 - loss: 0.0851 - val_accuracy: 0.5659 - val_loss: 0.0934
# Epoch 39/100
#
# Epoch 39: val_accuracy improved from 0.56836 to 0.56888, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6000 - loss: 0.0844 - val_accuracy: 0.5689 - val_loss: 0.0935
# Epoch 40/100
#
# Epoch 40: val_accuracy did not improve from 0.56888
# 810/810 - 69s - 85ms/step - accuracy: 0.6015 - loss: 0.0835 - val_accuracy: 0.5547 - val_loss: 0.0957
# Epoch 41/100
#
# Epoch 41: val_accuracy did not improve from 0.56888
# 810/810 - 69s - 85ms/step - accuracy: 0.6032 - loss: 0.0829 - val_accuracy: 0.5677 - val_loss: 0.0928
# Epoch 42/100
#
# Epoch 42: val_accuracy improved from 0.56888 to 0.56926, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6073 - loss: 0.0819 - val_accuracy: 0.5693 - val_loss: 0.0918
# Epoch 43/100
#
# Epoch 43: val_accuracy did not improve from 0.56926
# 810/810 - 69s - 85ms/step - accuracy: 0.6078 - loss: 0.0812 - val_accuracy: 0.5629 - val_loss: 0.0931
# Epoch 44/100
#
# Epoch 44: val_accuracy improved from 0.56926 to 0.57365, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6118 - loss: 0.0804 - val_accuracy: 0.5736 - val_loss: 0.0922
# Epoch 45/100
#
# Epoch 45: val_accuracy improved from 0.57365 to 0.57554, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6135 - loss: 0.0798 - val_accuracy: 0.5755 - val_loss: 0.0905
# Epoch 46/100
#
# Epoch 46: val_accuracy improved from 0.57554 to 0.57706, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6176 - loss: 0.0786 - val_accuracy: 0.5771 - val_loss: 0.0912
# Epoch 47/100
#
# Epoch 47: val_accuracy improved from 0.57706 to 0.57818, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6197 - loss: 0.0783 - val_accuracy: 0.5782 - val_loss: 0.0900
# Epoch 48/100
#
# Epoch 48: val_accuracy improved from 0.57818 to 0.58121, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6208 - loss: 0.0775 - val_accuracy: 0.5812 - val_loss: 0.0897
# Epoch 49/100
#
# Epoch 49: val_accuracy improved from 0.58121 to 0.58341, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6244 - loss: 0.0767 - val_accuracy: 0.5834 - val_loss: 0.0892
# Epoch 50/100
#
# Epoch 50: val_accuracy did not improve from 0.58341
# 810/810 - 69s - 85ms/step - accuracy: 0.6271 - loss: 0.0762 - val_accuracy: 0.5755 - val_loss: 0.0914
# Epoch 51/100
#
# Epoch 51: val_accuracy improved from 0.58341 to 0.58835, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6292 - loss: 0.0755 - val_accuracy: 0.5884 - val_loss: 0.0892
# Epoch 52/100
#
# Epoch 52: val_accuracy did not improve from 0.58835
# 810/810 - 69s - 85ms/step - accuracy: 0.6316 - loss: 0.0748 - val_accuracy: 0.5815 - val_loss: 0.0892
# Epoch 53/100
#
# Epoch 53: val_accuracy did not improve from 0.58835
# 810/810 - 69s - 85ms/step - accuracy: 0.6336 - loss: 0.0742 - val_accuracy: 0.5786 - val_loss: 0.0889
# Epoch 54/100
#
# Epoch 54: val_accuracy improved from 0.58835 to 0.58955, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6369 - loss: 0.0738 - val_accuracy: 0.5895 - val_loss: 0.0880
# Epoch 55/100
#
# Epoch 55: val_accuracy did not improve from 0.58955
# 810/810 - 69s - 85ms/step - accuracy: 0.6384 - loss: 0.0730 - val_accuracy: 0.5888 - val_loss: 0.0875
# Epoch 56/100
#
# Epoch 56: val_accuracy did not improve from 0.58955
# 810/810 - 69s - 85ms/step - accuracy: 0.6410 - loss: 0.0722 - val_accuracy: 0.5867 - val_loss: 0.0882
# Epoch 57/100
#
# Epoch 57: val_accuracy did not improve from 0.58955
# 810/810 - 69s - 85ms/step - accuracy: 0.6416 - loss: 0.0722 - val_accuracy: 0.5863 - val_loss: 0.0887
# Epoch 58/100
#
# Epoch 58: val_accuracy did not improve from 0.58955
# 810/810 - 69s - 85ms/step - accuracy: 0.6442 - loss: 0.0712 - val_accuracy: 0.5811 - val_loss: 0.0893
# Epoch 59/100
#
# Epoch 59: val_accuracy improved from 0.58955 to 0.59283, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6456 - loss: 0.0711 - val_accuracy: 0.5928 - val_loss: 0.0863
# Epoch 60/100
#
# Epoch 60: val_accuracy improved from 0.59283 to 0.59524, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 86ms/step - accuracy: 0.6475 - loss: 0.0706 - val_accuracy: 0.5952 - val_loss: 0.0864
# Epoch 61/100
#
# Epoch 61: val_accuracy did not improve from 0.59524
# 810/810 - 69s - 85ms/step - accuracy: 0.6497 - loss: 0.0698 - val_accuracy: 0.5913 - val_loss: 0.0879
# Epoch 62/100
#
# Epoch 62: val_accuracy improved from 0.59524 to 0.60018, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6513 - loss: 0.0695 - val_accuracy: 0.6002 - val_loss: 0.0855
# Epoch 63/100
#
# Epoch 63: val_accuracy did not improve from 0.60018
# 810/810 - 69s - 85ms/step - accuracy: 0.6537 - loss: 0.0690 - val_accuracy: 0.5953 - val_loss: 0.0868
# Epoch 64/100
#
# Epoch 64: val_accuracy did not improve from 0.60018
# 810/810 - 69s - 85ms/step - accuracy: 0.6534 - loss: 0.0690 - val_accuracy: 0.5991 - val_loss: 0.0855
# Epoch 65/100
#
# Epoch 65: val_accuracy did not improve from 0.60018
# 810/810 - 69s - 85ms/step - accuracy: 0.6557 - loss: 0.0685 - val_accuracy: 0.5983 - val_loss: 0.0861
# Epoch 66/100
#
# Epoch 66: val_accuracy improved from 0.60018 to 0.60234, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6574 - loss: 0.0679 - val_accuracy: 0.6023 - val_loss: 0.0848
# Epoch 67/100
#
# Epoch 67: val_accuracy did not improve from 0.60234
# 810/810 - 69s - 85ms/step - accuracy: 0.6595 - loss: 0.0672 - val_accuracy: 0.5955 - val_loss: 0.0878
# Epoch 68/100
#
# Epoch 68: val_accuracy improved from 0.60234 to 0.60364, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6612 - loss: 0.0669 - val_accuracy: 0.6036 - val_loss: 0.0846
# Epoch 69/100
#
# Epoch 69: val_accuracy improved from 0.60364 to 0.60688, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6639 - loss: 0.0664 - val_accuracy: 0.6069 - val_loss: 0.0835
# Epoch 70/100
#
# Epoch 70: val_accuracy did not improve from 0.60688
# 810/810 - 69s - 85ms/step - accuracy: 0.6645 - loss: 0.0661 - val_accuracy: 0.6062 - val_loss: 0.0839
# Epoch 71/100
#
# Epoch 71: val_accuracy improved from 0.60688 to 0.60719, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6673 - loss: 0.0655 - val_accuracy: 0.6072 - val_loss: 0.0831
# Epoch 72/100
#
# Epoch 72: val_accuracy improved from 0.60719 to 0.60744, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6675 - loss: 0.0655 - val_accuracy: 0.6074 - val_loss: 0.0837
# Epoch 73/100
#
# Epoch 73: val_accuracy improved from 0.60744 to 0.60852, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6704 - loss: 0.0648 - val_accuracy: 0.6085 - val_loss: 0.0841
# Epoch 74/100
#
# Epoch 74: val_accuracy improved from 0.60852 to 0.61110, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6722 - loss: 0.0644 - val_accuracy: 0.6111 - val_loss: 0.0831
# Epoch 75/100
#
# Epoch 75: val_accuracy did not improve from 0.61110
# 810/810 - 69s - 85ms/step - accuracy: 0.6722 - loss: 0.0643 - val_accuracy: 0.6098 - val_loss: 0.0832
# Epoch 76/100
#
# Epoch 76: val_accuracy did not improve from 0.61110
# 810/810 - 69s - 85ms/step - accuracy: 0.6745 - loss: 0.0641 - val_accuracy: 0.6080 - val_loss: 0.0835
# Epoch 77/100
#
# Epoch 77: val_accuracy improved from 0.61110 to 0.61323, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6764 - loss: 0.0634 - val_accuracy: 0.6132 - val_loss: 0.0833
# Epoch 78/100
#
# Epoch 78: val_accuracy did not improve from 0.61323
# 810/810 - 69s - 85ms/step - accuracy: 0.6761 - loss: 0.0632 - val_accuracy: 0.6132 - val_loss: 0.0833
# Epoch 79/100
#
# Epoch 79: val_accuracy improved from 0.61323 to 0.61722, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6764 - loss: 0.0633 - val_accuracy: 0.6172 - val_loss: 0.0820
# Epoch 80/100
#
# Epoch 80: val_accuracy did not improve from 0.61722
# 810/810 - 69s - 85ms/step - accuracy: 0.6768 - loss: 0.0628 - val_accuracy: 0.6170 - val_loss: 0.0829
# Epoch 81/100
#
# Epoch 81: val_accuracy did not improve from 0.61722
# 810/810 - 69s - 85ms/step - accuracy: 0.6789 - loss: 0.0626 - val_accuracy: 0.6130 - val_loss: 0.0828
# Epoch 82/100
#
# Epoch 82: val_accuracy did not improve from 0.61722
# 810/810 - 69s - 85ms/step - accuracy: 0.6816 - loss: 0.0621 - val_accuracy: 0.6121 - val_loss: 0.0837
# Epoch 83/100
#
# Epoch 83: val_accuracy did not improve from 0.61722
# 810/810 - 69s - 85ms/step - accuracy: 0.6806 - loss: 0.0622 - val_accuracy: 0.6166 - val_loss: 0.0814
# Epoch 84/100
#
# Epoch 84: val_accuracy improved from 0.61722 to 0.61794, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6840 - loss: 0.0614 - val_accuracy: 0.6179 - val_loss: 0.0812
# Epoch 85/100
#
# Epoch 85: val_accuracy improved from 0.61794 to 0.62006, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6856 - loss: 0.0612 - val_accuracy: 0.6201 - val_loss: 0.0817
# Epoch 86/100
#
# Epoch 86: val_accuracy improved from 0.62006 to 0.62010, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6857 - loss: 0.0610 - val_accuracy: 0.6201 - val_loss: 0.0817
# Epoch 87/100
#
# Epoch 87: val_accuracy improved from 0.62010 to 0.62166, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6879 - loss: 0.0606 - val_accuracy: 0.6217 - val_loss: 0.0811
# Epoch 88/100
#
# Epoch 88: val_accuracy did not improve from 0.62166
# 810/810 - 69s - 85ms/step - accuracy: 0.6873 - loss: 0.0607 - val_accuracy: 0.6120 - val_loss: 0.0843
# Epoch 89/100
#
# Epoch 89: val_accuracy improved from 0.62166 to 0.62508, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6876 - loss: 0.0605 - val_accuracy: 0.6251 - val_loss: 0.0811
# Epoch 90/100
#
# Epoch 90: val_accuracy did not improve from 0.62508
# 810/810 - 69s - 85ms/step - accuracy: 0.6915 - loss: 0.0597 - val_accuracy: 0.6219 - val_loss: 0.0815
# Epoch 91/100
#
# Epoch 91: val_accuracy did not improve from 0.62508
# 810/810 - 69s - 85ms/step - accuracy: 0.6901 - loss: 0.0599 - val_accuracy: 0.6139 - val_loss: 0.0837
# Epoch 92/100
#
# Epoch 92: val_accuracy did not improve from 0.62508
# 810/810 - 69s - 85ms/step - accuracy: 0.6908 - loss: 0.0599 - val_accuracy: 0.6173 - val_loss: 0.0818
# Epoch 93/100
#
# Epoch 93: val_accuracy improved from 0.62508 to 0.62566, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6927 - loss: 0.0590 - val_accuracy: 0.6257 - val_loss: 0.0814
# Epoch 94/100
#
# Epoch 94: val_accuracy did not improve from 0.62566
# 810/810 - 69s - 85ms/step - accuracy: 0.6948 - loss: 0.0590 - val_accuracy: 0.6247 - val_loss: 0.0819
# Epoch 95/100
#
# Epoch 95: val_accuracy did not improve from 0.62566
# 810/810 - 69s - 85ms/step - accuracy: 0.6931 - loss: 0.0591 - val_accuracy: 0.6163 - val_loss: 0.0831
# Epoch 96/100
#
# Epoch 96: val_accuracy improved from 0.62566 to 0.62936, saving model to checkpoints/best_model_modified_v2.keras
# 810/810 - 69s - 85ms/step - accuracy: 0.6935 - loss: 0.0591 - val_accuracy: 0.6294 - val_loss: 0.0802
# Epoch 97/100
#
# Epoch 97: val_accuracy did not improve from 0.62936
# 810/810 - 69s - 85ms/step - accuracy: 0.6958 - loss: 0.0586 - val_accuracy: 0.6211 - val_loss: 0.0819
# Epoch 98/100
#
# Epoch 98: val_accuracy did not improve from 0.62936
# 810/810 - 69s - 85ms/step - accuracy: 0.6965 - loss: 0.0583 - val_accuracy: 0.6263 - val_loss: 0.0811
# Epoch 99/100
#
# Epoch 99: val_accuracy did not improve from 0.62936
# 810/810 - 69s - 85ms/step - accuracy: 0.6978 - loss: 0.0580 - val_accuracy: 0.6279 - val_loss: 0.0812
# Epoch 100/100
#
# Epoch 100: val_accuracy did not improve from 0.62936
# 810/810 - 69s - 85ms/step - accuracy: 0.6977 - loss: 0.0582 - val_accuracy: 0.6249 - val_loss: 0.0805
# Restoring model weights from the end of the best epoch: 96.

# %%
import shutil

# 1. Zip the entire checkpoints folder
shutil.make_archive('/kaggle/working/checkpoints_backup_v4', 'zip', '/kaggle/working/checkpoints')
# Out:
# '/kaggle/working/checkpoints_backup_v4.zip'

# %%
@register_keras_serializable()
def attention_context(x):
    return tf.reduce_sum(x[0] * x[1], axis=1)

@register_keras_serializable()
def attention_output_shape(input_shapes):
    return (input_shapes[0][0], input_shapes[0][2])

@register_keras_serializable(name="loss")
def focal_loss_wrapper(gamma=2.0, alpha=0.25):
    def loss(y_true, y_pred):
        y_pred = tf.clip_by_value(y_pred, 1e-8, 1. - 1e-8)
        cross_entropy = -y_true * tf.math.log(y_pred)
        weight = alpha * tf.pow(1 - y_pred, gamma)
        loss = weight * cross_entropy
        return tf.reduce_mean(tf.reduce_sum(loss, axis=1))
    return loss

# %%
from keras.models import load_model

model = load_model(
    'checkpoints/best_model_modified_v2.keras',
    custom_objects={
        'loss': focal_loss_wrapper(),
        'attention_context': attention_context,
        'attention_output_shape': attention_output_shape
    }
)

# %%
from sklearn.metrics import classification_report
import numpy as np

# Предсказания
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

# Отчёт по классам
print(classification_report(y_true, y_pred, target_names=['Down', 'Neutral', 'Up'], digits=4))
# Out:
# 2025-05-25 18:59:21.297294: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 1620/1620 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step
#               precision    recall  f1-score   support
#
#         Down     0.6806    0.7005    0.6904     27485
#      Neutral     0.5881    0.4854    0.5319     12214
#           Up     0.5525    0.6132    0.5813     12117
#
#     accuracy                         0.6294     51816
#    macro avg     0.6071    0.5997    0.6012     51816
# weighted avg     0.6288    0.6294    0.6275     51816

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

# Матрица ошибок
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Down', 'Neutral', 'Up'])
disp.plot(cmap='Blues', values_format='d')
plt.title("Confusion Matrix")
plt.show()
